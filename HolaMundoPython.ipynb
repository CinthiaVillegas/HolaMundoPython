# %% [markdown]
# <a href="https://colab.research.google.com/github/CinthiaVillegas/HolaMundoPython/blob/main/HolaMundoPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HolaMundoPython
# Aqui se tendra registro de mi avance aprendiendo Python con el Curso de Rodolfo Ferro y Ricardo Mirón, Sherpas de Innovacción México.
#
# By: Cinthia Villegas Soto
# Date: 25/02/2021

# %% [markdown]
# # Inicio
#
# Hola mundo, será el primer ejercicio para este curso de Python.
# Aqui hacemos uso del metodo print() que nos mostrará en pantalla lo que colocamos entre las " ".
#
# **Por ejemplo:** Si queremos que nuestra consola nos regrese un mensaje tenemos que ...
#
#
# > *print ("**mensaje**")*
#
#
# Donde **mensaje** es la cadena de texto que queremos que se muestre en consola.

# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %% [markdown]
# # Funciones de entrada y salida de datos
#
# ![IMG_20210225_202714314.jpg](data:image/jpeg;base64,...)

# %%
nombre = input("Introduce tu nombre: ")
print(f"Mucho gusto, {nombre}")
# Out:
# Introduce tu nombre: Cinthia
# Mucho gusto, Cinthia

# %% [markdown]
# # Variables con diferentes datos(tipado dinamico)
#
# **Variable**: el nombre de las variables tienen que iniciar con una letra y se puede separar con una letra mayuscula en la segunda palabra o con un guión bajo _. Por ejemplo: HeladoLimon, heladoLimon, helado_limon

# %%
name = "Cinthia"
age = 22
pi = 3.1416

#Impresion en pantalla de las variables declaradas
print("Nombre: ",name," Edad: ", age, " PI= ", pi)
#Impresion del tipo de dato de cada variable
print("Nombre= ",type(name)," Edad= ", type(age)," PI = ", type(pi))

#Casteo de una variable con valor entero  a una varible con valor flotante (decimal)
age = float(age)
print("Edad: ",age)
print("Edad= ",type(age))
# Out:
# Nombre:  Cinthia  Edad:  22  PI=  3.1416
# Nombre=  <class 'str'>  Edad=  <class 'int'>  PI =  <class 'float'>
# Edad:  22.0
# Edad=  <class 'float'>

# %% [markdown]
# # Operaciones básicas y condiciones
#
# Existen 3 tipos de operaciones básicas:
# * Aritméticas: Suma (a + b), Resta (a - b), Multiplicación (a * b),  División (a / b), Cociente de la división( a // b ), Resto de la división (a % b), Potencia a^b (a ** b)
#
# * Comparación: Mayor que(>), Menor que(<), Mayor igual(>=), Menor igual(<=), igualdad(==), diferencia(!=)
#
# * Lógicas: and, or, not
#
#
# Los condicionales los utilizaremos para validar si se cumple una o más condiciones para ejecutar cierto bloque de código

# %%
a = float(input("Valor de A = "))
b = float(input("Valor de B = "))

print("** Variables ** A= ",a,"   B= ",b)

print("== Operaciones aritmeticas ==")

print("Suma = ", a + b)
print("Resta = ", a - b)
print("Multiplicación = ", a * b)
print("División = ", a / b)
print("Cociente = ", a // b)
print("Resto = ", a % b)
print("Potencia = ", a ** b)

print("== Operaciones de comparación ==")
if (a>b or a>=b):
 print("A es mayor igual que B")
elif (a<b or a<=b):
 print("A es menor igual que B")
elif (a==b):
 print("A tiene el mismo valor que B")
# Out:
# Valor de A = 2
# Valor de B = 2
# ** Variables ** A=  2.0    B=  2.0
# == Operaciones aritmeticas ==
# Suma =  4.0
# Resta =  0.0
# Multiplicación =  4.0
# División =  1.0
# Cociente =  1.0
# Resto =  0.0
# Potencia =  4.0
# == Operaciones de comparación ==
# A es mayor igual que B

# %% [markdown]
# # Listas y tuplas
#
#
# Una lista no es lo mismo que una tupla. Ambas son un conjunto ordenado de valores, en donde este último puede ser cualquier objeto: un número, una cadena, una función, una clase, una instancia, etc. La diferencia es que las listas presentan una serie de funciones adicionales que permiten un amplio manejo de los valores que contienen. Basándonos en esta definición, puede decirse que las listas son dinámicas, mientras que las tuplas son estáticas.
#
# **Nota:**
#
# * Los valores de una lista van dentro de **[ ]**
# * Los valores de una tupla van dentro de **( )**
# * Los valores de un diccionario de datos van dentro de **{ }**
#
# **Por ejemplo:**
#
# lista = [león, tigre, conejo]
#
# tupla = (león, tigre, conejo)
#
# dic = {
#     "dia": 4,
#     "mes": "Agosto"
# }

# %%
print("==============================================")
print("============ Listas y tuplas =================")
print("==============================================")

#Ejemplo de lista
zoo_l = [
    "león",
    "tigre",
    "oso",
    "tucán",
    "pavo real"
    ]
#Imprime valores dentro de la lista
print("Lista => ", zoo_l) 

#Dentro de la lista cada valor tiene una posición empezando desde 0 hasta N
#Si mandamos a imprimir la lista con un valor designado, solo se mostrará el valor que se encuentra en esa posición
#En caso de colocar un valor designado fuera de las posiciones de la lista nos ocurrira un error
print("Posición 2 => ",zoo_l[1])
print("Posición 5 => ",zoo_l[4])

#Para saber la longitud de la lista, es decir, cuantas posiciones tiene
print("Longitud de la lista => ",len(zoo_l))

#Para cambiar el valor que se tiene en una posición determinada basta con hacer lo siguiente
var = "Dinosaurio"
print("Valor por el que será sustituido => ", var)
print("Valor que se tiene antes del cambio=> ", zoo_l[2])
zoo_l[2] = var
print("Valor que se tiene despues del cambio => ", zoo_l[2])
print("Lista final => ", zoo_l) 
print("")
print("==============================================")
print("")
#Ejemplo de tupla, similar a una lista, solo que una tupla es inmutable, es decir, que sus valores son estaticos
zoo_t = (
    "león",
    "tigre",
    "oso",
    "tucán",
    "pavo real"
    )
#Imprime valores dentro de la tupla
print("Tupla => ", zoo_t)
# Out:
# ...
# ============ Listas y tuplas =================
# ...
# Lista =>  ['león', 'tigre', 'oso', 'tucán', 'pavo real']
# Posición 2 =>  tigre
# Posición 5 =>  pavo real
# Longitud de la lista =>  5
# Valor por el que será sustituido =>  Dinosaurio
# Valor que se tiene antes del cambio=>  oso
# Valor que se tiene despues del cambio =>  Dinosaurio
# Lista final =>  ['león', 'tigre', 'Dinosaurio', 'tucán', 'pavo real']
#
# ...
#
# Tupla =>  ('león', 'tigre', 'oso', 'tucán', 'pavo real')

# %% [markdown]
# # Uso de IN (Palabra reservada)
# IN, es usado para valir si un dato X forma parte de una coleccion de datos (tupla o lista)

# %%
print("Animales en el zoologico *la lista* => ",zoo_l)
"perro" in zoo_l
ani = input("Animal que deseas encontrar en el zoo = ")
if ani in zoo_l:
    print("Si esta")
else:
    print("Pronto llegará")
# Out:
# Animales en el zoologico *la lista* =>  ['león', 'tigre', 'Dinosaurio', 'tucán', 'pavo real']
# Animal que deseas encontrar en el zoo = tigre
# Si esta
